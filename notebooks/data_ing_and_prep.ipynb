# %%
import os
import pandas as pd
# import nltk

# %%
import nltk

# Download the 'punkt' tokenizer
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/semre/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import pandas as pd

# Load the dataset from an Excel file
data = pd.read_excel('/home/semre/ethio_mart_tg_Ecomerse/data/telegram_data.xlsx', header=None)

# Check the first few rows to understand its structure
print(data.head())

# Manually assign column names
data.columns = ['Channel Title', 'Channel Username', 'ID', 'Message', 'Date', 'Media Path']  # Change these names accordingly

# Now you can access the 'Message' column
print("Checking for NaN values in the 'Message' column:")
nan_count = data['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
#                      0                   1     2        3  \
# 0        Channel Title    Channel Username    ID  Message
# 1  Sheger online-store  @Shageronlinestore  5333      NaN
# 2  Sheger online-store  @Shageronlinestore  5332      NaN
# 3  Sheger online-store  @Shageronlinestore  5331      NaN
# 4  Sheger online-store  @Shageronlinestore  5330      NaN
#
#                            4                                   5
# 0                       Date                          Media Path
# 1  2024-09-20 11:50:03+00:00  photos/@Shageronlinestore_5333.jpg
# 2  2024-09-20 11:50:03+00:00  photos/@Shageronlinestore_5332.jpg
# 3  2024-09-20 11:50:03+00:00  photos/@Shageronlinestore_5331.jpg
# 4  2024-09-20 11:50:02+00:00  photos/@Shageronlinestore_5330.jpg
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 1849

# %%
print(data.columns)
# Out:
# Index(['Channel Title', 'Channel Username', 'ID', 'Message', 'Date',
#        'Media Path'],
#       dtype='object')

# %%
print("Checking for NaN values in the 'Message' column:")
nan_count = data['Message'].isnull().sum()
print(f"Number of NaN values in 'Message' column: {nan_count}")
# Out:
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 1849

# %%
data = data.dropna(subset=['Message'])

# Print the shape of the dataset after dropping NaN values in the "Message" column
print(f"Dataset shape after dropping NaN values in 'Message' column: {data.shape}")
# Out:
# Dataset shape after dropping NaN values in 'Message' column: (3167, 6)

# %%
data.head()
# Out:
#          Channel Title    Channel Username    ID  \
# 0        Channel Title    Channel Username    ID
# 6  Sheger online-store  @Shageronlinestore  5328
# 7  Sheger online-store  @Shageronlinestore  5327
# 8  Sheger online-store  @Shageronlinestore  5326
# 9  Sheger online-store  @Shageronlinestore  5325
#
#                                              Message  \
# 0                                            Message
# 6  💥3pcs silicon brush spatulas\n\n⚡እስከ 260°c ሙቀት...
# 7  💥Mandoline Slicer\n\n👉 ጊዜ ቆጣቢ ስላይስ ማድረጊያ \n👉  ...
# 8  💥Table Desk Edge Guard Strip\n       💯 High Qu...
# 9  💥Table Desk Edge Guard Strip\n       💯 High Qu...
#
#                         Date                          Media Path
# 0                       Date                          Media Path
# 6  2024-09-20 11:50:02+00:00  photos/@Shageronlinestore_5328.jpg
# 7  2024-09-20 08:11:40+00:00                                 NaN
# 8  2024-09-20 05:23:18+00:00                                 NaN
# 9  2024-09-20 05:21:14+00:00  photos/@Shageronlinestore_5325.jpg

# %%
message_data=data['Message']
message_data
# Out:
# 0                                                 Message
# 6       💥3pcs silicon brush spatulas\n\n⚡እስከ 260°c ሙቀት...
# 7       💥Mandoline Slicer\n\n👉 ጊዜ ቆጣቢ ስላይስ ማድረጊያ \n👉  ...
# 8       💥Table Desk Edge Guard Strip\n       💯 High Qu...
# 9       💥Table Desk Edge Guard Strip\n       💯 High Qu...
#                               ...
# 5010    🎯 Kitchen Sticker\n\nለኪችንዎ ውበት እጅግ ተመራጭ \n🔰ውሀ ...
# 5011    🎯 3in1 One Step Hair Dryer & Styler \n\n👉 ከርል ...
# 5012    ✅ Home GYM - X5 slimming vibrator \n\n📢📢📢 ታላቅ ...
# 5013    ለጤናችን-Health & Personal Care\n\n📍FingerTip Pul...
# 5014    #Finger_tip_pulse_oximeter\n       #በተመጣጣኝ_ዋጋ\...
# Name: Message, Length: 3167, dtype: object

# %%
# Example of your DataFrame
# df = pd.DataFrame({'Message': ['💥3pcs silicon brush spatulas...', '💥Mandoline Slicer...', ...]})

# Define a function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile(
        "[" 
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251" 
        "]+", 
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# Apply the function to the 'Message' column
data['Message'] = data['Message'].apply(remove_emojis)

# Display the updated DataFrame
print(data.head())
# Out:
#          Channel Title    Channel Username    ID  \
# 0        Channel Title    Channel Username    ID
# 6  Sheger online-store  @Shageronlinestore  5328
# 7  Sheger online-store  @Shageronlinestore  5327
# 8  Sheger online-store  @Shageronlinestore  5326
# 9  Sheger online-store  @Shageronlinestore  5325
#
#                                              Message  \
# 0                                            Message
# 6  3pcs silicon brush spatulas\n\nእስከ 260°c ሙቀት መ...
# 7  Mandoline Slicer\n\n ጊዜ ቆጣቢ ስላይስ ማድረጊያ \n  ለእጅ...
# 8  Table Desk Edge Guard Strip\n        High Qual...
# 9  Table Desk Edge Guard Strip\n        High Qual...
#
#                         Date                          Media Path
# 0                       Date                          Media Path
# 6  2024-09-20 11:50:02+00:00  photos/@Shageronlinestore_5328.jpg
# 7  2024-09-20 08:11:40+00:00                                 NaN
# 8  2024-09-20 05:23:18+00:00                                 NaN
# 9  2024-09-20 05:21:14+00:00  photos/@Shageronlinestore_5325.jpg

# %%
data.to_csv('clean_data.csv')

# %%
data
# Out:
#             Channel Title    Channel Username    ID  \
# 0           Channel Title    Channel Username    ID
# 6     Sheger online-store  @Shageronlinestore  5328
# 7     Sheger online-store  @Shageronlinestore  5327
# 8     Sheger online-store  @Shageronlinestore  5326
# 9     Sheger online-store  @Shageronlinestore  5325
# ...                   ...                 ...   ...
# 5010  Sheger online-store  @Shageronlinestore    12
# 5011  Sheger online-store  @Shageronlinestore    10
# 5012  Sheger online-store  @Shageronlinestore     9
# 5013  Sheger online-store  @Shageronlinestore     4
# 5014  Sheger online-store  @Shageronlinestore     3
#
#                                                 Message  \
# 0                                               Message
# 6     3pcs silicon brush spatulas\n\nእስከ 260°c ሙቀት መ...
# 7     Mandoline Slicer\n\n ጊዜ ቆጣቢ ስላይስ ማድረጊያ \n  ለእጅ...
# 8     Table Desk Edge Guard Strip\n        High Qual...
# 9     Table Desk Edge Guard Strip\n        High Qual...
# ...                                                 ...
# 5010   Kitchen Sticker\n\nለኪችንዎ ውበት እጅግ ተመራጭ \nውሀ የማ...
# 5011   3in1 One Step Hair Dryer & Styler \n\n ከርል ለመ...
# 5012   Home GYM - X5 slimming vibrator \n\n ታላቅ ቅናሽ ...
# 5013  ለጤናችን-Health & Personal Care\n\nFingerTip Puls...
# 5014  #Finger_tip_pulse_oximeter\n       #በተመጣጣኝ_ዋጋ\...
#
#                            Date                          Media Path
# 0                          Date                          Media Path
# 6     2024-09-20 11:50:02+00:00  photos/@Shageronlinestore_5328.jpg
# 7     2024-09-20 08:11:40+00:00                                 NaN
# 8     2024-09-20 05:23:18+00:00                                 NaN
# 9     2024-09-20 05:21:14+00:00  photos/@Shageronlinestore_5325.jpg
# ...                         ...                                 ...
# 5010  2021-04-27 05:58:59+00:00    photos/@Shageronlinestore_12.jpg
# 5011  2021-04-27 05:57:12+00:00    photos/@Shageronlinestore_10.jpg
# 5012  2021-04-27 05:45:57+00:00     photos/@Shageronlinestore_9.jpg
# 5013  2021-04-12 08:36:40+00:00     photos/@Shageronlinestore_4.jpg
# 5014  2021-04-12 08:35:47+00:00     photos/@Shageronlinestore_3.jpg
#
# [3167 rows x 6 columns]

# %%
import re

def label_message_utf8_with_birr(message):
    # Split the message at the first occurrence of '\n'
    if '\n' in message:
        first_line, remaining_message = message.split('\n', 1)
    else:
        first_line, remaining_message = message, ""
    
    labeled_tokens = []
    
    # Tokenize the first line
    first_line_tokens = re.findall(r'\S+', first_line)
    
    # Label the first token as B-PRODUCT and the rest as I-PRODUCT
    if first_line_tokens:
        labeled_tokens.append(f"{first_line_tokens[0]} B-PRODUCT")  # First token as B-PRODUCT
        for token in first_line_tokens[1:]:
            labeled_tokens.append(f"{token} I-PRODUCT")  # Remaining tokens as I-PRODUCT
    
    # Process the remaining message normally
    if remaining_message:
        lines = remaining_message.split('\n')
        for line in lines:
            tokens = re.findall(r'\S+', line)  # Tokenize each line while considering non-ASCII characters
            
            for token in tokens:
                # Check if token is a price (e.g., 500 ETB, $100, or ብር)
                if re.match(r'^\d{10,}$', token):
                    labeled_tokens.append(f"{token} O")  # Label as O for "other" or outside of any entity
                elif re.match(r'^\d+(\.\d{1,2})?$', token) or 'ETB' in token or 'ዋጋ' in token or '$' in token or 'ብር' in token:
                    labeled_tokens.append(f"{token} I-PRICE")
                # Check if token could be a location (e.g., cities or general location names)
                elif any(loc in token for loc in ['Addis Ababa', 'ለቡ', 'ለቡ መዳህኒዓለም', 'መገናኛ', 'ቦሌ', 'ሜክሲኮ']):
                    labeled_tokens.append(f"{token} I-LOC")
                # Assume other tokens are part of a product name or general text
                else:
                    labeled_tokens.append(f"{token} O")
    
    return "\n".join(labeled_tokens)

# Apply the updated function to the non-null messages
data['Labeled_Message'] = data['Message'].apply(label_message_utf8_with_birr)

# Display the updated DataFrame
data.head()
# Out:
#          Channel Title    Channel Username    ID  \
# 0        Channel Title    Channel Username    ID
# 6  Sheger online-store  @Shageronlinestore  5328
# 7  Sheger online-store  @Shageronlinestore  5327
# 8  Sheger online-store  @Shageronlinestore  5326
# 9  Sheger online-store  @Shageronlinestore  5325
#
#                                              Message  \
# 0                                            Message
# 6  3pcs silicon brush spatulas\n\nእስከ 260°c ሙቀት መ...
# 7  Mandoline Slicer\n\n ጊዜ ቆጣቢ ስላይስ ማድረጊያ \n  ለእጅ...
# 8  Table Desk Edge Guard Strip\n        High Qual...
# 9  Table Desk Edge Guard Strip\n        High Qual...
#
#                         Date                          Media Path  \
# 0                       Date                          Media Path
# 6  2024-09-20 11:50:02+00:00  photos/@Shageronlinestore_5328.jpg
# 7  2024-09-20 08:11:40+00:00                                 NaN
# 8  2024-09-20 05:23:18+00:00                                 NaN
# 9  2024-09-20 05:21:14+00:00  photos/@Shageronlinestore_5325.jpg
#
#                                      Labeled_Message
# 0                                  Message B-PRODUCT
# 6  3pcs B-PRODUCT\nsilicon I-PRODUCT\nbrush I-PRO...
# 7  Mandoline B-PRODUCT\nSlicer I-PRODUCT\nጊዜ O\nቆ...
# 8  Table B-PRODUCT\nDesk I-PRODUCT\nEdge I-PRODUC...
# 9  Table B-PRODUCT\nDesk I-PRODUCT\nEdge I-PRODUC...

# %%
# Save the updated labeled dataset to a file in CoNLL format
labeled_data_birr_path = 'labeled_telegram_product_price_location.txt-'
with open(labeled_data_birr_path, 'w', encoding='utf-8') as f:
    for index, row in data.iterrows():
        f.write(f"{row['Labeled_Message']}\n\n")
